# %% [markdown]
# # **4. Model + Dropout, Batch Normalization and Data Augmentation**

# %% [markdown]
# First of all, let's load the required libraries in order to run the code:

# %%
# Base libraries
import os

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Tensorflow
import tensorflow.keras as keras
from tensorflow.keras import optimizers
from tensorflow.keras import models, layers
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Own modules
from src.utils import drop_checkpoints, dataset_stats, plot_metric_curves

# %% [markdown]
# Now let's see how our data is structured:

# %%
# Root folder
base_dir = "./data"

# %%
# Train folder
train_dir = os.path.join(base_dir, "train")

# Validation folder
validation_dir = os.path.join(base_dir, "validation")

# Test folder
test_dir = os.path.join(base_dir, "test")

# %%
drop_checkpoints(base_dir)

# %% [markdown]
# Let's also see how many images there are for each class in the training, validation and test set.

# %%
dataset_stats(train_dir, validation_dir, test_dir)
# Out:
# Number of classes: 4
# Existing classes: ['Baroque', 'Realism', 'Renaissance', 'Romanticism']
#
# ----------------------------------------
# Number of images per class and dataset:
# ----------------------------------------
#              Train  Validation  Test
# Style
# Baroque       4000         500   500
# Realism       4000         500   500
# Renaissance   4000         500   500
# Romanticism   4000         500   500

# %% [markdown]
# We'll also create the directory, if not created yet, where the models will be saved:

# %%
# Create directory where to save the models created
models_dir = "./models"
os.makedirs(models_dir, exist_ok=True)

# %% [markdown]
# *Explain dropout and data augmentation, include reference to original paper*

# %% [markdown]
# ### 3.1. Model structure
#
# Let's first create the model structure:

# %% [markdown]
# Firstly, let's define the values of some hyperparameters:

# %%
# Define some hyperparameters' values

# Input shape
input_shape = (256, 256,  3)

# Batch_size and steps per epoch
training_size = sum([len(file) for path, folder, file in os.walk(train_dir)])
batch_size = 128
steps_per_epoch = training_size // batch_size
print(f"Steps per epoch: {steps_per_epoch}")
# Out:
# Steps per epoch: 125

# %%
model = models.Sequential()
# 1st Convolution Layer
model.add(layers.Conv2D(32, (3, 3), activation='relu',
                        input_shape=input_shape
                        )
)
# 1st Pooling Layer
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.BatchNormalization())

# 2nd Convolution Layer
model.add(layers.Conv2D(64, 
                        (3, 3), 
                        activation='relu'
                       )
         )
# 2nd Pooling Layer
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.BatchNormalization())

# 3rd Convolution Layer
model.add(layers.Conv2D(128, 
                        (3, 3), 
                        activation='relu'
                        )
)
# 3rd Pooling Layer
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.BatchNormalization())

# 4th Convolution Layer
model.add(layers.Conv2D(128, 
                        (3, 3), 
                        activation='relu'
                        )
)
# 4th Pooling Layer
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.BatchNormalization())

model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dropout(0.5))

#model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(4, activation='softmax'))

# %% [markdown]
# Once the structure of the base model has been defined, let's see exactly how many parameters it has in order to have a better idea of how flexible this model is:

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 32)     0
#  )
#
#  batch_normalization (BatchN  (None, 127, 127, 32)     128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 64)       0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 62, 62, 64)       256
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 30, 30, 128)      0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 30, 30, 128)      512
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 128)       147584
#
#  max_pooling2d_3 (MaxPooling  (None, 14, 14, 128)      0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 14, 14, 128)      512
#  hNormalization)
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 512)               12845568
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 13,089,860
# Trainable params: 13,089,156
# Non-trainable params: 704
# _________________________________________________________________

# %% [markdown]
# We'll use Adam as our optimizer since it is the most popular optimizer right now, as well as versatile (i.e., it can be used in multiple contexts).

# %%
model.compile(
    loss='categorical_crossentropy',
    optimizer=optimizers.Adam(learning_rate=1e-4),
    #optimizer='adam',
    metrics=['acc']
)

# %% [markdown]
# ### 1.2. Data preprocessing
#
# In this case, we will include the Data Augmentation step to the model preprocessing step...

# %%
# Apply data augmentation to the training set
# https://towardsdatascience.com/exploring-image-data-augmentation-with-keras-and-tensorflow-a8162d89b844
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=5,
    width_shift_range=0.1,
    height_shift_range=0.1,
    brightness_range=(0.9, 1),
    zoom_range=[0.95, 1.05],
    horizontal_flip=True,
    fill_mode='nearest'
    )

#train_datagen = ImageDataGenerator(
    #rescale = 1./255.,
    #rotation_range= 5,
    #zoom_range=0.05,
    #horizontal_flip=True,
#)

# The data augmentation must not be used for the test set!
# All images will be rescaled by 1./255
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        train_dir,
        # All images will be resized to the dimensions specified
        target_size=input_shape[:2],
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=True
        )

validation_generator = test_datagen.flow_from_directory(
        validation_dir,
        # All images will be resized to the dimensions specified
        target_size=input_shape[:2],
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=False
        )
# Out:
# Found 16000 images belonging to 4 classes.
# Found 2000 images belonging to 4 classes.

# %% [markdown]
# Now let's take a look at the output of one of these generators (for instance, the training one):

# %%
for data_batch, labels_batch in train_generator:
    print('Data batch shape:', data_batch.shape)
    print('Labels batch shape:', labels_batch.shape)
    break
# Out:
# Data batch shape: (128, 256, 256, 3)
# Labels batch shape: (128, 4)

# %% [markdown]
# *We can appreciate that...*

# %% [markdown]
# ### 1.3. Training
#
# Let's train the model:

# %% [markdown]
# We use [Early Stopping](https://machinelearningmastery.com/how-to-stop-training-deep-neural-networks-at-the-right-time-using-early-stopping/) to avoid *overfitting*, as well `ModelCheckpoint` to save the best model obtained during training:

# %%
# Model name and path
model_path = os.path.join("models", "augmentation_model.h5")

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
mc = ModelCheckpoint(model_path, monitor='val_loss', 
                     mode='min', verbose=1, save_best_only=True)

# %%
history = model.fit(
    train_generator,
    steps_per_epoch=steps_per_epoch,
    epochs=30,
    validation_data=validation_generator,
    validation_steps=10,
    callbacks = [es, mc]
)
# Out:
# Epoch 1/30
#   4/125 [..............................] - ETA: 12:09 - loss: 2.3787 - acc: 0.3359
# c:\Users\carlo\anaconda3\envs\venv_art\lib\site-packages\PIL\TiffImagePlugin.py:858: UserWarning: Corrupt EXIF data.  Expecting to read 2 bytes but only got 0.
#   warnings.warn(str(msg))
# 125/125 [==============================] - ETA: 0s - loss: 1.8202 - acc: 0.4423
# Epoch 1: val_loss improved from inf to 1.98282, saving model to models\augmentation_model.h5
# 125/125 [==============================] - 705s 6s/step - loss: 1.8202 - acc: 0.4423 - val_loss: 1.9828 - val_acc: 0.3906
# Epoch 2/30
# 125/125 [==============================] - ETA: 0s - loss: 1.4602 - acc: 0.4909
# Epoch 2: val_loss did not improve from 1.98282
# 125/125 [==============================] - 675s 5s/step - loss: 1.4602 - acc: 0.4909 - val_loss: 2.6310 - val_acc: 0.3930
# Epoch 3/30
# 125/125 [==============================] - ETA: 0s - loss: 1.3328 - acc: 0.5171
# Epoch 3: val_loss improved from 1.98282 to 1.30731, saving model to models\augmentation_model.h5
# 125/125 [==============================] - 674s 5s/step - loss: 1.3328 - acc: 0.5171 - val_loss: 1.3073 - val_acc: 0.4328
# Epoch 4/30
# 125/125 [==============================] - ETA: 0s - loss: 1.2581 - acc: 0.5291
# Epoch 4: val_loss improved from 1.30731 to 1.29664, saving model to models\augmentation_model.h5
# 125/125 [==============================] - 690s 6s/step - loss: 1.2581 - acc: 0.5291 - val_loss: 1.2966 - val_acc: 0.4953
# Epoch 5/30
# 125/125 [==============================] - ETA: 0s - loss: 1.1922 - acc: 0.5501
# Epoch 5: val_loss improved from 1.29664 to 1.16985, saving model to models\augmentation_model.h5
# 125/125 [==============================] - 691s 6s/step - loss: 1.1922 - acc: 0.5501 - val_loss: 1.1699 - val_acc: 0.6023
# Epoch 6/30
# 125/125 [==============================] - ETA: 0s - loss: 1.1544 - acc: 0.5598
# Epoch 6: val_loss did not improve from 1.16985
# 125/125 [==============================] - 694s 6s/step - loss: 1.1544 - acc: 0.5598 - val_loss: 1.4862 - val_acc: 0.5578
# Epoch 7/30
# 125/125 [==============================] - ETA: 0s - loss: 1.0988 - acc: 0.5773
# Epoch 7: val_loss did not improve from 1.16985
# 125/125 [==============================] - 676s 5s/step - loss: 1.0988 - acc: 0.5773 - val_loss: 1.2841 - val_acc: 0.5727
# Epoch 8/30
# 125/125 [==============================] - ETA: 0s - loss: 1.0687 - acc: 0.5795
# Epoch 8: val_loss did not improve from 1.16985
# 125/125 [==============================] - 676s 5s/step - loss: 1.0687 - acc: 0.5795 - val_loss: 1.1780 - val_acc: 0.6266
# Epoch 9/30
# 125/125 [==============================] - ETA: 0s - loss: 1.0421 - acc: 0.5919
# Epoch 9: val_loss did not improve from 1.16985
# 125/125 [==============================] - 677s 5s/step - loss: 1.0421 - acc: 0.5919 - val_loss: 1.1755 - val_acc: 0.6187
# Epoch 10/30
# 125/125 [==============================] - ETA: 0s - loss: 1.0132 - acc: 0.6014
# Epoch 10: val_loss did not improve from 1.16985
# 125/125 [==============================] - 660s 5s/step - loss: 1.0132 - acc: 0.6014 - val_loss: 1.4456 - val_acc: 0.5836
# Epoch 10: early stopping

# %% [markdown]
# Now let's load the best model found:

# %%
# load the saved model
saved_model = load_model(model_path)

# %% [markdown]
# ### 1.4. Validation
#
# Let's plot how the loss and the accuracy from both training and validations sets have evolved during the training process.

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

# %%
# Plot loss curves
plot_metric_curves(epochs, loss, val_loss, "darkgreen", "lightgreen", "Loss")

# %%
# Plot accuracy curves
plot_metric_curves(epochs, acc, val_acc, "darkgreen", "lightgreen", "Accuracy")

# %%
# sns.set_theme()

# plt.figure(figsize=(15,10), dpi=200)

# plt.plot(epochs, acc, 'royalblue', linewidth=2, label='Training acc')
# plt.plot(epochs, val_acc, 'blueviolet', linewidth=2, label='Validation acc')
# plt.title('Training and validation accuracy', fontsize=20)
# plt.legend(frameon=False, fontsize=15)

# plt.show()

# plt.figure(figsize=(15,10), dpi=200)

# plt.plot(epochs, loss, 'royalblue', linewidth=2, label='Training loss')
# plt.plot(epochs, val_loss, 'blueviolet', linewidth=2, label='Validation loss')
# plt.title('Training and validation loss', fontsize=20)
# plt.legend(frameon=False, fontsize=15)

# plt.show()

# %%
test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=input_shape[:2],
        batch_size=40,
        class_mode='categorical',
        shuffle=False
        )
# Out:
# Found 2000 images belonging to 4 classes.

# %%
model.evaluate(test_generator)
# Out:
# 50/50 [==============================] - 47s 943ms/step - loss: 1.3300 - acc: 0.5755
# [1.3299739360809326, 0.5755000114440918]

# %%
saved_model.evaluate(test_generator)
# Out:
# 50/50 [==============================] - 44s 876ms/step - loss: 1.2042 - acc: 0.5385
# [1.2042485475540161, 0.5385000109672546]

# %% [markdown]
# *Comments about how those metrics have evolved...*
